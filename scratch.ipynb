# %%
import cfGPR

import numpy as np
# Out:
# WARNING: AstropyDeprecationWarning: astropy.extern.six will be removed in 4.0, use the six module directly if it is still needed [astropy.extern.six]

# %% [markdown]
# corr2d and params and function that the opt is using. make 2d plot of acutal data for corr function. make 2d plot of estimated function is, and the difference
#
# check uu+vv for the corr fit kernel and the real kernel

# %%
GP = cfGPR.CurlFreeGPR()

# %%
GP.load_fits('folio2')

# %%
GP.extract_data(465)

# %%
GP.sigma_clip()

# %%
GP.split_data(train_size=0.50)

# %%
GP.correlation_fit()

# %%
GP.print_params(GP.theta0)
# Out:
#  sigma_s: 339.85283        sigma_x: 0.26153          sigma_y: 0.19498              phi: 0.51925

# %%
GP.fit(GP.theta0)

# %%
GP.predict(GP.Xtest)

# %%
GP.plot_xiplus_2d(GP.Xtest, GP.Ytest, Y2=GP.fbar_s)

# %%
GP.plot_Emode_2ptcorr(GP.Xtest, GP.Ytest, Y2=GP.fbar_s)
# Out:
# Mean of first 30 points (Emode (Observed)):  435.7637604720614
# Mean of first 30 points (Bmode (Observed)):  -8.728176573820285
# Mean of first 30 points (Emode (GPR Applied)):  313.926072978666
# Mean of first 30 points (Bmode (GPR Applied)):  -6.22765320981517
# Ratio of E modes: 1.3881094881267644
# Ratio of B modes: 1.401519365282597

# %%
GP.optimize()
# Out:
# 1  : 2019-11-27 14:36:32.443270:  sigma_s: 339.85283        sigma_x: 0.26153          sigma_y: 0.19498              phi: 0.51925
# 2  : 2019-11-27 14:36:48.038656:  sigma_s: 390.83076        sigma_x: 0.26153          sigma_y: 0.19498              phi: 0.51925
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-91919198e2f8> in <module>
# ----> 1 GP.optimize()
#
# ~/DESworkspace/cfGPR.py in optimize(self, v0, fatol, xatol)
#     428             simplex0[0],
#     429             method='Nelder-Mead',
# --> 430             options=options
#     431         )
#     432
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     586                       callback=callback, **options)
#     587     elif meth == 'nelder-mead':
# --> 588         return _minimize_neldermead(fun, x0, args, callback, **options)
#     589     elif meth == 'powell':
#     590         return _minimize_powell(fun, x0, args, callback, **options)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     583
#     584     for k in range(N + 1):
# --> 585         fsim[k] = func(sim[k])
#     586
#     587     ind = numpy.argsort(fsim)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~/DESworkspace/cfGPR.py in get_nLML(self, theta)
#     303         self.print_params(theta, time=True, fix_phi=False, output=True)
#     304
# --> 305         self.fit(theta)
#     306 #         self.predict(self.Xvalid)
#     307 #         self.get_chisq(self.Yvalid, self.fbar_s, self.Evalid)
#
# ~/DESworkspace/cfGPR.py in fit(self, theta)
#     450         self.K = self.curl_free_kernel(self.theta, self.Xtrain, self.Xtrain)
#     451         self.W = self.white_noise_kernel(self.Etrain)
# --> 452         self.L = np.linalg.cholesky(self.K + self.W)
#     453         self.alpha = np.linalg.solve(self.L.T, np.linalg.solve(self.L, self.flat(self.Ytrain)))
#     454         self.nLML = -((-1/2) * np.dot(self.flat(self.Ytrain), self.alpha) - np.sum(np.log(np.diag(self.L))) - (self.nTest / 2) * np.log(2 * np.pi))
#
# <__array_function__ internals> in cholesky(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in cholesky(a)
#     757     t, result_t = _commonType(a)
#     758     signature = 'D->D' if isComplexType(t) else 'd->d'
# --> 759     r = gufunc(a, signature=signature, extobj=extobj)
#     760     return wrap(r.astype(result_t, copy=False))
#     761
#
# KeyboardInterrupt:

# %%
# GP = cfGPR.CurlFreeGPR()
# GP.load_fits('hoid')
# GP.extract_data(465)
# GP.sigma_clip()
# GP.split_data(train_size=0.50, test_size=0.50)

# %%
# GP.correlation_fit()
# GP.fit(GP.theta0)
# GP.predict(GP.Xtest)
# GP.get_chisq(GP.Ytest, GP.fbar_s, GP.Etest)
# GP.summarize()

# %%
# GP.optimize()
# GP.fit(GP.theta)
# GP.predict(GP.Xtest)
# GP.get_chisq(GP.Ytest, GP.fbar_s, GP.Etest)
# GP.summarize()
