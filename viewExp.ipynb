# %%
import GPRutils
import plotGPR

import numpy as np
import astropy.units as u
import matplotlib.pyplot as plt
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
exp = 791640
dC = GPRutils.loadNPZ(f"../thesis/{exp}/{exp}.npz")

# %%
x, y = dC.Xvalid.T*u.deg
dx, dy = dC.Yvalid.T*u.mas
err = np.sqrt(dC.Evalid_DES)*u.mas

x2, y2 = x, y
dx2, dy2 = dC.Yvalid.T*u.mas - dC.fbar_s.T*u.mas
err2 = err

# %%
xi = GPRutils.getXi(np.vstack([x, y]).T, np.vstack([dx, dy]).T)
xi2 = GPRutils.getXi(np.vstack([x, y]).T, np.vstack([dx2, dy2]).T)
ratio = xi[0] / xi2[0]
ratio
# Out:
# <Quantity 1.91392388>

# %%
# dC.quickPlot()

# %%
plotGPR.AstrometricResiduals(
    x, y, dx, dy, err,
    x2=x2, y2=y2, dx2=dx2, dy2=dy2, err2=err2,
    exposure=dC.expNum,
    scale=256*u.mas,
    pixelsPerBin=512,
    savePath="testexp"
)
# Out:
# /home/fortino/DESworkspace/GPRutils.py:761: RuntimeWarning: invalid value encountered in true_divide
#   sumWeights_x / sumWeights,
# /home/fortino/DESworkspace/GPRutils.py:765: RuntimeWarning: invalid value encountered in true_divide
#   sumWeights_y / sumWeights,
# /home/fortino/DESworkspace/GPRutils.py:769: RuntimeWarning: divide by zero encountered in reciprocal
#   sumWeights**-1.,
# /home/fortino/DESworkspace/GPRutils.py:780: RuntimeWarning: invalid value encountered in less
#   sumWeights < (maxErr**2.).value)
# /home/fortino/DESworkspace/GPRutils.py:787: RuntimeWarning: invalid value encountered in greater
#   RMS_x = np.std(sumWeights_x[sumWeights > 0.])*u.mas
# /home/fortino/DESworkspace/GPRutils.py:788: RuntimeWarning: invalid value encountered in greater
#   RMS_y = np.std(sumWeights_y[sumWeights > 0.])*u.mas
# /home/fortino/DESworkspace/GPRutils.py:789: RuntimeWarning: invalid value encountered in greater
#   noise = np.sqrt(np.mean(sumWeights[sumWeights > 0.]))*u.mas

# %%
plotGPR.DivCurl(
    x, y, dx, dy, err,
    x2=x2, y2=y2, dx2=dx2, dy2=dy2, err2=err2,
    exposure=dC.expNum,
    pixelsPerBin=1250,
    savePath="testexp"
)
# Out:
# /home/fortino/DESworkspace/GPRutils.py:761: RuntimeWarning: invalid value encountered in true_divide
#   sumWeights_x / sumWeights,
# /home/fortino/DESworkspace/GPRutils.py:765: RuntimeWarning: invalid value encountered in true_divide
#   sumWeights_y / sumWeights,
# /home/fortino/DESworkspace/GPRutils.py:769: RuntimeWarning: divide by zero encountered in reciprocal
#   sumWeights**-1.,
# /home/fortino/DESworkspace/GPRutils.py:780: RuntimeWarning: invalid value encountered in less
#   sumWeights < (maxErr**2.).value)
# /home/fortino/DESworkspace/GPRutils.py:787: RuntimeWarning: invalid value encountered in greater
#   RMS_x = np.std(sumWeights_x[sumWeights > 0.])*u.mas
# /home/fortino/DESworkspace/GPRutils.py:788: RuntimeWarning: invalid value encountered in greater
#   RMS_y = np.std(sumWeights_y[sumWeights > 0.])*u.mas
# /home/fortino/DESworkspace/GPRutils.py:789: RuntimeWarning: invalid value encountered in greater
#   noise = np.sqrt(np.mean(sumWeights[sumWeights > 0.]))*u.mas

# %%
plotGPR.Correlation(
    x, y, dx, dy,
    x2=x2, y2=y2, dx2=dx2, dy2=dy2,
    exposure=dC.expNum,
    ylim=(None, None),
#     xiB_ON=False,
#     xiE_ON=False,
#     xiplus_ON=True,
    savePath="testexp"
)
# Out:
# /home/fortino/DESworkspace/GPRutils.py:929: RuntimeWarning: invalid value encountered in true_divide
#   logr /= counts
# /home/fortino/DESworkspace/GPRutils.py:935: RuntimeWarning: invalid value encountered in true_divide
#   xiplus /= counts
# /home/fortino/DESworkspace/GPRutils.py:940: RuntimeWarning: invalid value encountered in true_divide
#   xiz2 /= counts
# /home/fortino/DESworkspace/GPRutils.py:949: RuntimeWarning: invalid value encountered in true_divide
#   ximinus /= counts
# /home/fortino/DESworkspace/plotGPR.py:502: RuntimeWarning: invalid value encountered in less_equal
#   ind = np.where(r <= sep.to(u.deg).value)[0]

# %%
plotGPR.Correlation2D(
    x, y, dx, dy,
    x2=x2, y2=y2, dx2=dx2, dy2=dy2,
    exposure=dC.expNum,
    nBins=75*4,
    vmin=0*u.mas**2,
    vmax=100*u.mas**2,
    rmax=0.5*4*u.deg,
    savePath="testexp"
)
# Out:
# /home/fortino/DESworkspace/GPRutils.py:1041: RuntimeWarning: divide by zero encountered in true_divide
#   xiplus /= counts
# /home/fortino/DESworkspace/GPRutils.py:1041: RuntimeWarning: invalid value encountered in true_divide
#   xiplus /= counts
